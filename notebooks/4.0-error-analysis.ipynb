# %% [markdown]
# # Imports/Settings

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# 1. Стандартная библиотека
import os
import sys
import warnings
from pathlib import Path
import joblib

# --- ДИНАМИЧЕСКИЙ РАСЧЕТ АБСОЛЮТНЫХ ПУТЕЙ ---
notebook_dir = Path(os.getcwd()).resolve()
if notebook_dir.name == "notebooks":
    PROJECT_ROOT = notebook_dir.parent
else:
    PROJECT_ROOT = notebook_dir

os.chdir(PROJECT_ROOT)

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# 2. Сторонние библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 3. Локальные модули
from src.core.data import DevDuckDBDataSource
from src.core.models import get_model
from src.core.splitting import split_data
from src.core.utils import load_hydra_config
from src.eda.visualisation import error_analyse, search_trends, worst_preds

# --- РАБОТА С ПРЕДУПРЕЖДЕНИЯМИ ---
warnings.filterwarnings('ignore', category=FutureWarning)

# --- ИНИЦИАЛИЗАЦИЯ HYDRA ---
load_hydra_config.cache_clear()
cfg = load_hydra_config()

run_name = Path(cfg.run_name)
reports_dir = Path(cfg.paths.reports_dir / run_name)
reports_dir.mkdir(parents=True, exist_ok=True)

print(f"Проект: {cfg.project_name} | Режим: Error Analysis")

# --- НАСТРОЙКИ ВИЗУАЛИЗАЦИИ ---
try:
    p_cfg = cfg.logging.plots
    plt.style.use(p_cfg.style)
    plt.rcParams.update({
        'figure.figsize': p_cfg.fig_size,
        'figure.dpi': p_cfg.dpi,
        'font.size': p_cfg.font_size,
        'axes.grid': p_cfg.grid,
        'axes.spines.top': p_cfg.spines_top,
        'axes.spines.right': p_cfg.spines_right
    })
    PLOT_ALPHA = p_cfg.alpha
except AttributeError:
    PLOT_ALPHA = 0.5
    print("Используются дефолтные стили Matplotlib.")
# Out:
# Проект: credit-risk-model | Режим: Error Analysis

# %% [markdown]
# # Data Loading

# %%
loader = DevDuckDBDataSource(cfg, PROJECT_ROOT)
df = loader.load()
_, val_df, _ = split_data(cfg, df)

target = cfg.data.tabular.target_col
X_val, y_val = val_df.drop(columns=[target]), val_df[target]

print(f"Размер выборки для анализа: {X_val.shape}")
# Out:
# Размер выборки для анализа: (39276, 61)

# %%
# --- ЗАГРУЗКА АРТЕФАКТОВ ИЗ ПАПКИ MODELS ---
models_dir = PROJECT_ROOT / cfg.paths.models_dir
model_version = cfg.model.model_version
preprocessor_version = cfg.data.tabular.preprocessing_version
model_name = cfg.model.name

print("Загрузка препроцессора и весов модели...")
prep = joblib.load(models_dir / f"preprocessing_v{preprocessor_version}.pkl")

model = get_model(cfg, project_root=PROJECT_ROOT)
model.load(str(models_dir / f"{model_name}_v{model_version}.cbm"))
# Out:
# Загрузка препроцессора и весов модели...

# %% [markdown]
# # Errors Analise

# %%
X_val_clean = prep.transform(X_val)
preds = model.predict(X_val_clean)

# Создаем базовый датафрейм для анализа
error_df = X_val.copy()
error_df['Actual'] = y_val.values
error_df['Predicted'] = preds

error_analyse(model=model, error_df=error_df, X_val_clean=X_val_clean, cfg=cfg, project_root=PROJECT_ROOT)

# %% [markdown]
# # Search Trends

# %%
search_trends(error_df=error_df, cfg=cfg, project_root=PROJECT_ROOT)
# Out:
# Категориальных признаков для анализа не найдено.

# %% [markdown]
# # Worst Preds

# %%
worst_preds(error_df=error_df, cfg=cfg, project_root=PROJECT_ROOT)
# Out:
# === ЗАПУСК ЛОКАЛЬНОГО АНАЛИЗА ОШИБОК | РЕЖИМ: BINARY ===
# === ОТЧЕТ ПО ХУДШИМ ОШИБКАМ КЛАССИФИКАЦИИ ===
# Версия фичей: 0.0.0 | Версия препроцессинга: 0.0.0
# ======================================================================
#
#  ТОП-5 FALSE POSITIVE (Модель уверенно ждала конверсию, но её не было):
#   • Строка [ID 3474] | Вероятность модели: 0.914
#     - pre_since_opened: 18.0
#     - pre_since_confirmed: 0.0
#     - pre_pterm: 0.0
#     - pre_fterm: 8.0
#     - pre_till_pclose: 8.0
#   ---------------------------------------------
#   • Строка [ID 2551] | Вероятность модели: 0.902
#     - pre_since_opened: 12.0
#     - pre_since_confirmed: 2.0
#     - pre_pterm: 4.0
#     - pre_fterm: 3.0
#     - pre_till_pclose: 7.0
#   ---------------------------------------------
#   • Строка [ID 35592] | Вероятность модели: 0.895
#     - pre_since_opened: 17.0
#     - pre_since_confirmed: 17.0
#     - pre_pterm: 4.0
#     - pre_fterm: 8.0
#     - pre_till_pclose: 1.0
#   ---------------------------------------------
#   • Строка [ID 14960] | Вероятность модели: 0.887
#     - pre_since_opened: 12.0
#     - pre_since_confirmed: 0.0
#     - pre_pterm: 4.0
#     - pre_fterm: 3.0
#     - pre_till_pclose: 7.0
#   ---------------------------------------------
#   • Строка [ID 21024] | Вероятность модели: 0.877
#     - pre_since_opened: 18.0
#     - pre_since_confirmed: 9.0
#     - pre_pterm: 4.0
#     - pre_fterm: 8.0
#     - pre_till_pclose: 1.0
#   ---------------------------------------------
#
#  ТОП-5 FALSE NEGATIVE (Конверсия была, но модель её полностью пропустила):
#   • Строка [ID 14116] | Вероятность модели: 0.059
#     - pre_since_opened: 0.0
#     - pre_since_confirmed: 10.0
#     - pre_pterm: 6.0
#     - pre_fterm: 8.0
#     - pre_till_pclose: 0.0
#   ---------------------------------------------
#   • Строка [ID 5910] | Вероятность модели: 0.150
#     - pre_since_opened: 4.0
#     - pre_since_confirmed: 0.0
#     - pre_pterm: 14.0
#     - pre_fterm: 8.0
#     - pre_till_pclose: 8.0
#   ---------------------------------------------
#   • Строка [ID 952] | Вероятность модели: 0.164
#     - pre_since_opened: 5.0
#     - pre_since_confirmed: 16.0
#     - pre_pterm: 6.0
#     - pre_fterm: 8.0
#     - pre_till_pclose: 0.0
#   ---------------------------------------------
#   • Строка [ID 15331] | Вероятность модели: 0.168
#     - pre_since_opened: 17.0
#     - pre_since_confirmed: 9.0
#     - pre_pterm: 1.0
#     - pre_fterm: 16.0
#     - pre_till_pclose: 12.0
#   ---------------------------------------------
#   • Строка [ID 2161] | Вероятность модели: 0.168
#     - pre_since_opened: 5.0
#     - pre_since_confirmed: 10.0
#     - pre_pterm: 6.0
#     - pre_fterm: 8.0
#     - pre_till_pclose: 0.0
#   ---------------------------------------------
#
# ✅ Локальные отчеты успешно сгенерированы и сохранены:
#    - Графики сохранены в: C:\credit-risk-model\reports\p_v0.0.0__f_v0.0.0__m_v0.0.0\worst_errors_plots_v0.0.0.png
#    - Текстовое досье сохранено в: C:\credit-risk-model\reports\p_v0.0.0__f_v0.0.0__m_v0.0.0\worst_errors_profile_v0.0.0.txt
